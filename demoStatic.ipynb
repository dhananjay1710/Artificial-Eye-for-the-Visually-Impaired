# %%
pip install gtts
# Out:
# Requirement already satisfied: gtts in c:\users\harsh\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: gtts-token>=1.1.4 in c:\users\harsh\anaconda3\lib\site-packages (from gtts) (1.1.4)
# Requirement already satisfied: requests in c:\users\harsh\anaconda3\lib\site-packages (from gtts) (2.21.0)
# Requirement already satisfied: six in c:\users\harsh\anaconda3\lib\site-packages (from gtts) (1.12.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\harsh\anaconda3\lib\site-packages (from gtts) (4.7.1)
# Requirement already satisfied: click in c:\users\harsh\anaconda3\lib\site-packages (from gtts) (7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\anaconda3\lib\site-packages (from requests->gtts) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\harsh\anaconda3\lib\site-packages (from requests->gtts) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\harsh\anaconda3\lib\site-packages (from requests->gtts) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\harsh\anaconda3\lib\site-packages (from requests->gtts) (2.8)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\harsh\anaconda3\lib\site-packages (from beautifulsoup4->gtts) (1.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
tf.test.gpu_device_name()
# Out:
# 2.3.1
# ''

# %%
import cv2
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
import tensorflow as tf
from yolov3.yolov4 import Create_Yolo
from yolov3.utils import load_yolo_weights, detect_image
from yolov3.configs import *

if YOLO_TYPE == "yolov4":
    Darknet_weights = YOLO_V4_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V4_WEIGHTS
if YOLO_TYPE == "yolov3":
    Darknet_weights = YOLO_V3_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V3_WEIGHTS

yolo = Create_Yolo(input_size=YOLO_INPUT_SIZE)
load_yolo_weights(yolo, Darknet_weights) # use Darknet weights

# %%
from gtts import gTTS
import os

# %%
def getLoc(x,y,width,height):
    loc = {
        "top left":((0,width/3),(0,height/3)),
        "top":((width/3,(2*width)/3),(0,height/3)),
        "top right":(((2*width)/3,width),(0,height/3)),
        "middle left":((0,width/3),(height/3,(2*height)/3)),
        "middle":((width/3,(2*width)/3),(height/3,(2*height)/3)),
        "middle right":(((2*width)/3,width),(height/3,(2*height)/3)),
        "bottom left":((0,width/3),((2*height)/3,height)),
        "bottom":((width/3,(2*width)/3),((2*height)/3,height)),
        "bottom right":(((2*width)/3,width),((2*height)/3,height)),
    }
    pos = ""
    for key in loc:
        xr = loc[key][0]
        xy = loc[key][1]
        if (x >= xr[0] and x<xr[1]) and (y>=xy[0] and y<xy[1]):
            pos = key
            
    return pos

# %%
image_path   = "./IMAGES/bottle.jpeg"

image,cl = detect_image(yolo, image_path, '', input_size=YOLO_INPUT_SIZE, show=False, rectangle_colors=(255,0,0))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#print(cl["bottle"])

height, width = image.shape[:2]
#print(height)
#print(width)

input_s = ""

plt.figure(figsize=(30,15))
plt.imshow(image)

for key in cl:
    #print(type(key))
    for y in cl[key]:
        x = (y[0] + y[2])/2
        y = (y[1] + y[3])/2
        ans = getLoc(x,y,width,height)
        input_s = input_s + key + " at " + ans + " "
        status = safe()
        #print(ans)
        #print(type(ans))
        plt.scatter(x,y)
plt.show()
print(input_s)
# Out:
# bottle at middle

# %%
image_path   = "./IMAGES/street.jpg"


image,cl = detect_image(yolo, image_path, '', input_size=YOLO_INPUT_SIZE, show=False, rectangle_colors=(255,0,0))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#print(cl["bottle"])

height, width = image.shape[:2]
#print(height)
#print(width)

input_s = ""

plt.figure(figsize=(30,15))
plt.imshow(image)

for key in cl:
    #print(type(key))
    for y in cl[key]:
        x = (y[0] + y[2])/2
        y = (y[1] + y[3])/2
        ans = getLoc(x,y,width,height)
        input_s = input_s + key + " at " + ans + " "
        #print(ans)
        #print(type(ans))
        plt.scatter(x,y)
plt.show()
print(input_s)
output = gTTS(text = input_s,lang = 'en',slow = False)
output.save("d1.mp3")
os.system("start d1.mp3")
# Out:
# person at middle right person at middle person at middle left person at middle left person at middle left person at middle left person at top right person at middle left person at middle left handbag at middle car at middle bus at middle bus at middle right
# 0

# %%
image_path   = "./IMAGES/demoimg.jpg"

image,cl = detect_image(yolo, image_path, '', input_size=YOLO_INPUT_SIZE, show=False, rectangle_colors=(255,0,0))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#print(cl["bottle"])

height, width = image.shape[:2]
#print(height)
#print(width)

input_s = ""

plt.figure(figsize=(30,15))
plt.imshow(image)

for key in cl:
    #print(type(key))
    for y in cl[key]:
        x = (y[0] + y[2])/2
        y = (y[1] + y[3])/2
        ans = getLoc(x,y,width,height)
        input_s = input_s + key + " at " + ans + " "
        #print(ans)
        #print(type(ans))
        plt.scatter(x,y)
plt.show()
print(input_s)
output = gTTS(text = input_s,lang = 'en',slow = False)
output.save("d1.mp3")
os.system("start d1.mp3")
# Out:
# dog at bottom left umbrella at bottom right
# 0

# %%
image_path   = "./IMAGES/demoimg2.jpg"

image,cl = detect_image(yolo, image_path, '', input_size=YOLO_INPUT_SIZE, show=False, rectangle_colors=(255,0,0))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#print(cl["bottle"])

height, width = image.shape[:2]
#print(height)
#print(width)

input_s = ""

plt.figure(figsize=(30,15))
plt.imshow(image)

for key in cl:
    #print(type(key))
    for y in cl[key]:
        x = (y[0] + y[2])/2
        y = (y[1] + y[3])/2
        ans = getLoc(x,y,width,height)
        input_s = input_s + key + " at " + ans + " "
        #print(ans)
        #print(type(ans))
        plt.scatter(x,y)
plt.show()

output = gTTS(text = input_s,lang = 'en',slow = False)
output.save("d1.mp3")
os.system("start d1.mp3")
# Out:
# 0

# %%
image_path   = "./IMAGES/calc1.jpg"

image,cl = detect_image(yolo, image_path, '', input_size=YOLO_INPUT_SIZE, show=False, rectangle_colors=(255,0,0))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(cl)
# Out:
# {'aeroplane': [array([230.82722473,  71.73906708, 305.05227661, 132.20388794,
#          0.63851655,   4.        ])]}
